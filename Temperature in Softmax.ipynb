# %% [markdown]
# Lower the temperature higher the confidence

# %%
import torch
import torch.nn.functional as F

# %%
predictions = torch.log(torch.rand(3))

# %%
predictions
# Out:
# tensor([-1.2523, -0.2076, -1.3547])

# %%
F.softmax(predictions, dim=-1)
# Out:
# tensor([0.2107, 0.5990, 0.1902])

# %%
F.softmax(predictions / 0.5, dim=-1)
# Out:
# tensor([0.1011, 0.8166, 0.0823])

# %%
F.softmax(predictions / 0.1, dim=-1)
# Out:
# tensor([2.9031e-05, 9.9996e-01, 1.0428e-05])

# %%
F.softmax(predictions / 100, dim=-1)
# Out:
# tensor([0.3323, 0.3358, 0.3319])

# %%
F.softmax(predictions / 200, dim=-1)
# Out:
# tensor([0.3328, 0.3346, 0.3326])

# %%
F.softmax(predictions / 1000, dim=-1)
# Out:
# tensor([0.3332, 0.3336, 0.3332])

# %%
F.softmax(predictions / 10000, dim=-1)
# Out:
# tensor([0.3333, 0.3334, 0.3333])

# %%
F.softmax(predictions / 100000, dim=-1)
# Out:
# tensor([0.3333, 0.3333, 0.3333])

# %%
F.softmax(predictions / 1000000, dim=-1)
# Out:
# tensor([0.3333, 0.3333, 0.3333])
